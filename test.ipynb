# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sklearn
import scipy
import tensorflow as tf

print(f"matplotlib   {matplotlib.__version__}")
print(f"pandas       {pd.__version__}")
print(f"numpy        {np.__version__}")
print(f"scikit-learn {sklearn.__version__}")
print(f"scipy        {scipy.__version__}")
print(f"tensorflow   {tf.__version__}")
print()
print("All modules loaded successfully.")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772899049.090333    4170 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1772899052.045299    4170 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772899060.777672    4170 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# matplotlib   3.10.8
# pandas       3.0.1
# numpy        2.4.2
# scikit-learn 1.8.0
# scipy        1.17.1
# tensorflow   2.21.0
#
# All modules loaded successfully.
