# %%
# !pip install matplotx
# Out:
# Requirement already satisfied: matplotx in /usr/local/python/3.12.13/lib/python3.12/site-packages (0.3.10)
# Requirement already satisfied: matplotlib in /usr/local/python/3.12.13/lib/python3.12/site-packages (from matplotx) (3.10.8)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/python/3.12.13/lib/python3.12/site-packages (from matplotx) (2.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/python/3.12.13/lib/python3.12/site-packages (from matplotlib->matplotx) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/python/3.12.13/lib/python3.12/site-packages (from matplotlib->matplotx) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/python/3.12.13/lib/python3.12/site-packages (from matplotlib->matplotx) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/python/3.12.13/lib/python3.12/site-packages (from matplotlib->matplotx) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/python/3.12.13/lib/python3.12/site-packages (from matplotlib->matplotx) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/python/3.12.13/lib/python3.12/site-packages (from matplotlib->matplotx) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /usr/local/python/3.12.13/lib/python3.12/site-packages (from matplotlib->matplotx) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/python/3.12.13/lib/python3.12/site-packages (from matplotlib->matplotx) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/python/3.12.13/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->matplotx) (1.17.0)

# %%
import matplotx
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sklearn
import scipy
import tensorflow as tf

plt.style.use(matplotx.styles.ayu['light'])
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772904577.605956   16763 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1772904581.010025   16763 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772904589.492781   16763 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
fm_data = pd.read_csv("./fm_data.csv")
fm_data.head()
# Out:
#    Unnamed: 0 Username           Artist                          Track  \
# 0           0  Babs_05  Isobel Campbell     The Circus Is Leaving Town
# 1           1  Babs_05  Isobel Campbell                   Dusty Wreath
# 2           2  Babs_05  Isobel Campbell     Honey Child What Can I Do?
# 3           3  Babs_05  Isobel Campbell  It's Hard To Kill A Bad Thing
# 4           4  Babs_05  Isobel Campbell                Saturday's Gone
#
#                        Album         Date    Time
# 0  Ballad of the Broken Seas  31 Jan 2021   23:36
# 1  Ballad of the Broken Seas  31 Jan 2021   23:32
# 2  Ballad of the Broken Seas  31 Jan 2021   23:28
# 3  Ballad of the Broken Seas  31 Jan 2021   23:25
# 4  Ballad of the Broken Seas  31 Jan 2021   23:21

# %% [markdown]
# # Feature Engineering:
# - **Time periods:** Using the given timestamps, convert it to distinct time periods such as “Morning”, “Noon”, “Afternoon”, etc.
# - **Days of the week:** Convert the day column to find out whether a song is heavily played on weekends vs weekdays. This can suggest party / relaxed vibes or work / focus vibes. Different days of the week can be analysed.

# %%
# feature engineering

# %% [markdown]
# # Co-occurrence (Collaborative Vibes):
# - Use dimensionality reduction techniques like **PCA (Principal Component Analysis)** or **SVD** to compress this massive table into smaller numerical vectors (embeddings) for each track.
# - Build a **user-track matrix** (a table where rows are tracks, columns are users, and values are play counts).
